# %%
#python -m spacy download da_core_news_sm

import pandas as pd
import numpy as np

import nltk
import spacy

import requests
import json

# %% [markdown]
# ### Create term list

# %%
df = pd.read_csv('/work/SofieNørboMosegaard#5741/NLP/NLP-exam/data/reviews.csv')
df[:6]
# Out:
#                  Title                                                URL  \
# 0                Modig         https://www.ekkofilm.dk/anmeldelser/modig/
# 1          On the Road          https://www.ekkofilm.dk/anmeldelser/road/
# 2  Hestehviskeren Buck  https://www.ekkofilm.dk/anmeldelser/hestehvisk...
# 3         Marie Krøyer  https://www.ekkofilm.dk/anmeldelser/marie-kroyer/
# 4     Forbrydelsen III  https://www.ekkofilm.dk/anmeldelser/forbrydels...
# 5            Kapringen     https://www.ekkofilm.dk/anmeldelser/kapringen/
#
#                 Author        Date  Rating  \
# 0     Jakob Stegelmann  29/08/2012       6
# 1           Lars Movin  03/10/2012       3
# 2  nne-Sophie Thostrup  26/09/2012       4
# 3       Klaus Rifbjerg  26/09/2012       3
# 4     Bo Tao Michaëlis  23/09/2012       4
# 5   Jesper Bo Petersen  19/09/2012       5
#
#                                               Review Sentiment  ID  \
# 0  Modiger en Pixar-film, der ikke blot handler o...       pos   0
# 1  Filmatiseringen af Jack Kerouacs beat-romanOn ...       neg   1
# 2  Det er smukt og stemningsfuldt, når den amerik...       pos   2
# 3  I hver anden butik på Skt. Laurentiivej, som e...       neg   3
# 4  Et maltrakteret lig bliver fundet ude i Københ...       pos   4
# 5  ”Jeg elsker dig,” nærmest sprutter skibskokken...       pos   5
#
#          Title_cleaned                                     Review_cleaned
# 0                modig  modiger en pixarfilm der ikke blot handler om ...
# 1          on the road  filmatiseringen af jack kerouacs beatromanon t...
# 2  hestehviskeren buck  det er smukt og stemningsfuldt når den amerika...
# 3         marie krøyer  i hver anden butik på skt laurentiivej som er ...
# 4     forbrydelsen iii  et maltrakteret lig bliver fundet ude i københ...
# 5            kapringen  jeg elsker dig nærmest sprutter skibskokken mi...

# %% [markdown]
# ### Extract gender-specific terms

# %%
# Part-of-Speech (POS) tagging for adjectives and nouns

def extract_POS(text):
    """
    Extracts adjectives and nouns from the input text
    """
    doc = nlp(text)
    adjectives = [token.text for token in doc if token.pos_ == "ADJ"]
    nouns = [token.text for token in doc if token.pos_ == "NOUN"]
    return adjectives, nouns

# Apply function to extract POS tags
POS_results = df['Review_cleaned'].apply(extract_POS)

# Initialize empty lists to store the POS words
all_adjectives = []
all_nouns = []

# Loop through the POS results and extend the lists with individual words
for adjectives, nouns in POS_results:
    all_adjectives.extend(adjectives) # Flatten the lists
    all_nouns.extend(nouns)

# Get unique POS words
unique_adjectives = np.unique(all_adjectives).tolist()
unique_nouns = np.unique(all_nouns).tolist()

# %%
print(f'Length of the list with unique adjectives: {len(unique_adjectives)}')  # 22,631
print(f'Length of the list with unique nouns: {len(unique_nouns)}')  # 98,288

# %%
unique_adjectives_df = pd.DataFrame(unique_adjectives, columns = ["adjectives"])
unique_nouns_df = pd.DataFrame(unique_nouns, columns = ["nouns"])

# Save to .csv files
unique_adjectives_df.to_csv("/work/SofieNørboMosegaard#5741/NLP/exam_testing/data/unique_adjectives.csv", index = False)
unique_nouns_df.to_csv("/work/SofieNørboMosegaard#5741/NLP/exam_testing/data/unique_nouns.csv", index = False)

# %% [markdown]
# ### Extract gender-specific names

# %%
# Named Entity Recognition (NER) to extract names

def load_spacy():
    """
    The function loads the Danish spaCy 'da_core_news_sm' model
    """
    nlp = spacy.load("da_core_news_sm")
    return nlp

# For each review, extract entities identified as names (labeled as PERSON)
def extract_names(text):
    doc = nlp(text)
    names = [ent.text for ent in doc.ents if ent.label_ == "PER"]
    return names

# Load model
nlp = load_spacy()

# Apply function to extract all unique names
# obs, the names will be extracted from the non-cleaned text column (meaning all names are with capital first letter)
unique_names = list(set(df['Review'].apply(extract_names).sum()))

print(len(unique_names)) # 26,373
print(unique_names)

# %%
unique_names = pd.read_csv('/work/SofieNørboMosegaard#5741/NLP/exam_testing/data/unique_names.csv')

# %%
unique_names = pd.read_csv('/work/SofieNørboMosegaard#5741/NLP/exam_testing/data/unique_names.csv')
names = unique_names['0'].tolist()
len(names)
# Out:
# 26373

# %%
92daf247a5babd95d6a9ed0a48869621

# %%
API_KEY = "92daf247a5babd95d6a9ed0a48869621"

# %%
API_KEY = "add_api_key"

# Genderize API URL
API_URL = "https://api.genderize.io"

# API limit, 10 names per API request
batch_size = 10

# threshold
confidence_threshold = 0.75

# Initialize lists for male, female, and unknown names
male_names = []
female_names = []
unknown_names = []

# Fetch gender data for a batch of names
def fetch_gender(names_batch):
    params = {"apikey": API_KEY, "name[]": names_batch}
    response = requests.get(API_URL, params = params)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return []

# Process names in batches and classify gender
for i in range(0, len(names), batch_size): 
    
    batch = names[i:i + batch_size]
    print(f"Processing batch: {batch}")

    try:
        data = fetch_gender(batch)
        for entry in data:

            if "gender" in entry and "probability" in entry:

                if entry["probability"] >= confidence_threshold:

                    if entry["gender"] == "male":
                        male_names.append(entry["name"])

                    elif entry["gender"] == "female":
                        female_names.append(entry["name"])

                else:
                    unknown_names.append(entry["name"])
            else:
                unknown_names.append(entry["name"])
                
    except Exception as e:
        print(f"Error processing batch {batch}: {e}")
# Out:
# Processing batch: ['Gray', 'Christopher Kyle', 'Am Not Your Negrotil', 'Jared Leto', 'Martys', 'Alexandria', 'Otar', 'Kolya iLeviathan', 'Christina Sandberg', 'Square']
# Processing batch: ['Luca Bigazzi', 'Moder Teresa', 'BlumhousesHalloween KillsogFirestarter', 'somKidsogBully', 'Olaf Heine Johannessen', 'Travis Scott', 'Steven Knight', 'Sherilyn Fenn', 'Robert De Niro', 'Morgan Tsvangirai']
# Processing batch: ['Frasiers', 'Bradley Coopers', 'Johanne Louise Heiberg', 'Laurents', 'MI6-spionen Lorraine Broughton', 'Alia', 'Harrison Cosmo Krikoryan Jarvis', 'Compound V. Marie Moreau', 'Jokum Rohde', 'Jakob Lebech Krogh']
# Processing batch: ['Intolerable Cruelty', 'Mean Beans', 'Jack Nicholsons', 'Trevor Slattery', 'Kwame', 'Javier Botet', 'Matthew Scudder', 'Pink', 'Peter Quinn', 'Michelangelo Antonioni']
# Processing batch: ['Lovetil James Bonds', 'Martin Campbell', 'Alex Gibneys dokumentarCrazy', 'Juan', 'Mary Mack', 'Wolt', 'Peter Refn', 'Jack Blacks', 'Lulu Wilson', 'Palle Vedel']
# Processing batch: ['Julie Brockhorst Andersen', 'Almeria', 'Quentin TarantinosReservoir Dogs', 'Maintenanceaf', 'Postmand Per', 'Richard Phillips', 'Harrison Ford', 'Pål Waaktaar', 'Mileva Marich', 'Pedro Almodóvars']
# Processing batch: ['Batman Filmener', 'Mike Stangle', 'Lois', 'Justin Marks', 'Kenneth Lonergan', 'Jack Conrad', 'Trine', 'Mabry', 'Joy Bryant', 'Anders Baasmo Christiansen']
# Processing batch: ['Karl Strand', 'Jana', 'Europaer', 'Rohn', 'Marra', 'Dreyer', 'Arthur Manley', 'Frederik Paludan', 'Melisa Sözen', 'Went Fine']
# Processing batch: ['Komarov', 'Sven Methlings', 'Bernstein', 'Regis McKenna', 'Gulddreng', 'Guldpalme-vinder4', 'Red Rock', 'Mortytil', 'stilsikreBlue Ruinudfolder', 'Lucie Blackman']
# Processing batch: ['Jamie Foxx', 'Ib Schønbergs', 'Paul Giamattis Merlot-hadende', 'afGreen Room', 'Marianne Engberg', 'Erich Kästner', 'Phil Burbank', 'Elliot Anderson', 'H. C. Hansen', 'Arthur Miller']
# Processing batch: ['Trek Into', 'Lee Kang-shengs', 'Real', 'afLes Revenantsuden', 'Dr. Frankenstein', 'Stakkels Regitze', 'Craig Frank', 'Mette Frederiksens', 'Wanycz', 'Celia Imrie']
# Processing batch: ['Laurent Cantet', 'Aldis Hodge', 'Kirsten Olesen', '#MeToo-tiden', 'Marchant', 'Kate Mara', 'Lorne Malvo', 'Lord Asriel', 'Love Lies Bleedinger', 'Asterix']
# Processing batch: ['John O’Mara', 'Charles Wright Mills', 'Bahar Pars', 'Foxy Knoxy', 'Peter Kennard', 'The Avengers', 'Gaza', 'Schirachs', 'Gatiss', 'Amalie Næsby']
# Processing batch: ['Susan Lacy', 'Midlers', 'Sven', 'atThe Flight Attendanttrods', 'Joel Hyrland', 'Neon Demoner', 'Mikhail Khodorkovsky', 'Rian JohnsonsKnives Out', 'Bullet', 'Addis Ababa']
# Processing batch: ['Jonathan Demmes', 'Tayssir', 'Denny Love', 'Alex Holder', 'Ricks', 'Jan Ole Gerster', 'Karl-Gustav', 'Worry', 'Danmarkshistorien', 'Anders Thomas']
# Processing batch: ['Pierre Rochefort', 'Johan Schlüter', 'Jarrett Ellis', 'Ilses', 'McGuinness', 'Abigail Hill', 'Arnetts', 'Houssam', 'Signe Moldes', 'Watr Shower']
# Processing batch: ['Alice Winocour', 'Bats', 'Yarrow Cheney', 'Stephanie', 'senesteRocky-ogRambo-sequels', 'skilsmisse', 'Carter Hudson', 'Whitehalls', 'Laurie Andersson', 'Tomasz Wasilewski']
# Processing batch: ['Tommy Knight', 'Nicholas Barclay', 'Frank fraDonnie Darko', 'Jon Øigarden', 'Martin Miehe-Renard', 'Jasmila Zbanics', 'Dargis', 'Nicolas Pesce', 'ægtemand altså', 'Løve']
# Processing batch: ['Cecil B. DeMillesThe Greatest', 'Emil Larsson', 'megasuccesenSquid Game', 'Minnie’s Haberdashery', 'Steen Stig Lommer', 'Mike Leighs', 'Julen', 'Peter Alsted', 'Scooter Braun', 'MedJojo Rabbiter Taika']
# Processing batch: ['HalvmandFrederik Louis Hviid', 'Wonka', 'Karlo', 'Bent Ødegaard Andersens', 'Little', 'Pedro IvosVagabondog Sofie Nørgaard KampmarksTsunamiviste', 'Maude alias Malene Schwartz', 'Andrew Haighs fremragende45 Yearsfra', 'Welchman', 'Bernhard Kempler']
# Processing batch: ['Jamie Spears', 'Benjamin CantusHarvest', 'Teklas', 'Jarecki', 'Muslimsk', 'Milla Jovovich', 'stille zoom', 'Sheyi Cole', 'Miranda July', 'Englishman']
# Processing batch: ['Roland', 'Sisterhooder', 'Ishmael Muslim Ali', 'Dean-Charles Chapman', 'Jennifer Lawrence', 'Jojos', 'Holger Danske', 'Trinity', 'Luminita Gheorghius', 'Remo Girone']
# Processing batch: ['Chinese Widowden', 'Ann Forrest', 'Månen', 'Poppins', 'Bridgettes', 'Klan', 'Flerkamera', 'Guy Nattiv', 'Johan Fasting', 'Hancock']
# Processing batch: ['Lara', 'Dougie Jones', 'Claires', 'Lars Messerschmidt', 'IOrla FrøsnapperogGummi', 'Mikhail Aprosimov', 'Ridley Scott', 'Egentligt', 'Joen Højerslev', 'Marlon Langeland']
# Processing batch: ['James Theatre', 'Buñuels', 'Butch Cavendish', 'Matt Murdock', 'Daniel Brühl', 'Lee Christmas', 'Lars Halvorsens', 'Mattis Huus Heurlin', 'Edels', 'Liberal Alliance']
# Processing batch: ['Mulvads', 'Ljubomir Stefanov', 'Carinas', 'Lee Christopher', 'Patrick Dempsey', 'Little Prayersparker', 'Amelie', 'Karim Ainouz', 'Georg Madsen', 'An Exorcist Tells']
# Processing batch: ['Svend Åge Madsens', 'Poul Reumerts', 'Jane Foster', 'Brian Harper', 'GjordeTropic Thunderikke', 'Mutte Micaela Ramazzotti', 'Mia', 'Alex Jennings', 'Oscars', 'Corrin']
# Processing batch: ['Komikeren Will Forte', 'Robert Jordans', 'ErThe Late Showen', 'Uncertain Grace', 'Slagtebænk DybbølogSlaget', 'Dustin Hoffman', 'Peter Mullans', 'Ulysses Klaue', 'Lorenza Izzo', 'Jeté Laurence']
# Processing batch: ['Bashirog Susanne BiersBrødre', 'Odell', 'Fotograf Anders Nydam', 'Akerman', 'Erika Grace Strada', 'Paul Schaffer', 'Fader Tuck', 'Jack Horner', 'Kjærbye Kristensen', 'franskeLes Revenants']
# Processing batch: ['Godards', 'Jack Trainer', 'Scott Fischer', 'Spring Breakerser', 'Jennifer Lawrences', 'Pedro Luques', 'Justice League-heltegruppen', 'Toni Colette', 'Mallory', 'Bernadett']
# Processing batch: ['Sylvanian Village', 'Jack Ryans', 'Errol Morris’The Thin Blue', 'Tinder Swindlerkan', 'Kasey Jordan', 'miljødramaetErin Brockovich', 'Michael Noers', 'Espen Enger', 'Jesper Groth', 'Franklin J. Schaffners']
# Processing batch: ['Josto', 'Frey', 'Bill Sage', 'Preben Kristensen', 'Axelrod', 'Buenos Aires', 'Dominic Paris', 'Luke Bracey', 'Kodi', 'bjørn Kumatetsu']
# Processing batch: ['Coodie', 'Harper Lee', 'Mansons', 'Joseph Fiennes', 'Hanne Thomsen', 'Jesse Custer', 'Slimani', 'Momos', 'Reklamefolk', 'Elwood Dalton']
# Processing batch: ['Gingers', 'Boris Bertrams', 'medMaze Runner', 'Kurt', 'Mads Guldborg Bøge', 'Riklis', 'Masons', 'Mr. Hydeer', 'Mogens Sørensen', 'Søren Sveistrups']
# Processing batch: ['Mala Emde', 'Vorobyeva', 'Rastløse Raša', 'Ferdinand Marcos', 'Tim Burtons tårefremkaldendeEdward Saksehånd', 'Robert Duvall', 'Catherine Durant', 'Paul Liebermans', 'Weis', 'Jens Otto']
# Processing batch: ['Bojana', 'Barcelona-fan', 'John Carpenters horrorklassikerHalloween', 'fårBien Majapludselig', 'Ellen Hillingsøs', 'Ellie Sattler', 'Gene Cousineau', 'George Eliot', 'Olavi', 'McMillian']
# Processing batch: ['Matthieu Gonet', 'Three Flavours Cornetto”-trilogi', 'Cheers', 'Fugleskræmsel', 'Peter Pan-mand', 'Frankenstein', 'Mikael Salomon', 'Anatoliens', 'Max Fischer', 'Anne Reumert']
# Processing batch: ['Sidney Lumet', 'Ayatollah Khomeini', 'Saru', 'Vanya', 'Sorry We Missed You', 'Christian Bøving', 'Spil', 'Joan Botey', 'William Lee', 'Lasse Steen']
# Processing batch: ['Erlich Bachman', 'Mikael iBertelsen', 'Jean-Francois Richet', 'Bror Madigan', 'Boris Spasskij', 'Susanne BiersBird Boxvirker', 'IIn Brugesholdes', 'High Water', 'Real Lava', 'Tordenskjold']
# Processing batch: ['Joel Kinnaman', 'Rocky Balboa', 'Barrie', 'Sandvoort', 'Justin Roiland', 'Asier Etxeandia', 'Ben Barnes', 'Karl Markovics', 'Wilsons', 'Shirley Chisholm']
# Processing batch: ['Matthew Rhys', 'Karole', 'Roger Vadim', 'Saul Berenson', 'Kevin Macdonald', 'Shprësim', 'Terence Fletcher', 'John Benjamin Hickey', 'per hjemmevideo', 'Asger Jorn']
# Processing batch: ['Lauren Greenfield', 'John Malkovichs Marvin', 'Josh Appelbaum', 'Crazy Townsone', 'Freydis', 'Wilhelm Stuckart', 'Julius Onah', 'Dusty', 'Little Richard', 'Luke Evans']
# Processing batch: ['Hollywood-debutThe Dark', 'Jesper Wung-Sungs', 'Fjerma', 'Morfydd Clark', 'Liam Gallagher', 'Hossain', 'Velling', 'Waleed', 'Radisernes Søren Brun', 'Human']
# Processing batch: ['Amma', 'Krista Kosonen', 'Le Saule Pleureur', 'Sjöman', 'Vsevolod Pudovkin', 'Penny', 'AnnonceKnud Pedersen', 'Ida Grøn', 'Amy Sherman-Palladino', 'Påskeharen']
# Processing batch: ['Stauning', 'Promise', 'Tony Lip', 'Widners', 'Crockett Johnsons', 'Cake', 'Ludvig Mylius-Erichsen', 'Gore Verbinski', 'Naomi Osaka', 'Meinhard']
# Processing batch: ['Russel Crowe', 'Sara E. Zermoglio', 'Saga Studio', 'Samina Jakobsen Den', 'Kristian Boserup', 'Jack Reacher-karakteren', 'Onkel Reje', 'Kim Bodnia', 'Harry Potter-film', 'Skærmhackeren']
# Processing batch: ['iSan Andreaser', 'Yanggår', 'Ólafur Egilsson', 'Kristin', 'Hypnose', 'Soso', 'Marine Vacth', 'Charles Atlas', 'Frankie Martino', 'Bridget Everett']
# Processing batch: ['Farenslove', 'Nolent', 'John Duttons', 'Swanberg', 'Slaters', 'Brian Singer', 'Emil Prenter', 'Birgitte StærmosesAfterwar', 'Jon Shenk', 'Herbert']
# Processing batch: ['Catch Firesamt', 'Hans Hansen', 'Lorelei Linklater', 'Henrys', 'Rolf Kristian Larsens', 'Sofus Rønnov', 'Cloverfield Laneligner', 'Dascha Polanco', 'Shyamalan', 'Peter Parkers']
# Processing batch: ['Shirley Henderson', 'Elleville Elfrid', 'Massimilianos', 'Chris Pine', 'Jesper Juhl', 'Alexander Skarsgård', 'Gisp', 'Johannes', 'Alemanno', 'Atoz']
# Processing batch: ['Lado', 'Pierre Oscar Levy', 'Duttons', 'Beetlejuiceend', 'Alex Catalán', 'Washingtons', 'Vertov', 'Frank Hvams', 'Trofast', 'Datteren Belle']
# Processing batch: ['Martin Dirkovs', 'Godard Cinemavirker', 'Barbara', 'Pippi Olivia Norgaard Skov', 'Austin Keeling', 'Live Tinder', 'Kirby', 'Cornell Woolrichs', 'Peter Malberg', 'Morgan']
# Processing batch: ['Mados', 'Knate Lee', 'Hjertet', 'Jacques Prévert', 'Lashana Lynch', 'Mumitrolde', 'Munk', 'Komikeren Ray Romano', 'Jimmy Jerry Lee Jones', 'eksistensdramaFantasten']
# Processing batch: ['Bad', 'Zach Woods', 'Ridleys', 'Wong Kar-Wai-sædvane', 'Carol Duarte', 'DR3', 'Siddons', 'Swann Nambotin', 'John Crowley', 'Simon MortensensPinkies']
# Processing batch: ['Martin Bigums', 'John Waynes', 'Eleanor', 'Grevens Fejde', 'Cecil Hotel', 'Neel Rønholts', 'Harpers', 'MAGA-rallys', 'Franz Walter', 'Assange']
# Processing batch: ['Kaptajn Kidd', 'Hitchcock', 'Rune Klan', 'Amalie Kruse Jensen', 'Hilde', 'David Simone', 'Pigernes Ole', 'Anne Sofie Espersen', 'DokumentarenQ’s Barbershopsætter', 'Silk Spectre']
# Processing batch: ['Milos Forman', 'Cobb Vanth', 'Gorô', 'Stefanie Estes', 'Marie Amachoukeli-Barsacq', 'Lana Wachowskis', 'Comte Volpe', 'Long Halftime Walksin', 'Blade', 'Oscar-triumfThe Artist']
# Processing batch: ['Elia Suleiman', 'Affairundervejs', 'Ditte Lorensen-Coteret', 'Daenaerys Targaryen', 'Catelyn Stark', 'Got Served', 'Nicolas Becker', 'Call Saulmøder', 'Margos', 'Tysklands']
# Processing batch: ['Saeed', 'Zeke Tilson', 'Maurices', 'Suilven', 'Katie Aseltons', 'Alains', 'Letitia', 'Dominique Besnehard', 'Walt Whitman', 'Cavill']
# Processing batch: ['Jay Roach', 'Pie', 'Slate', 'Parkinsons-syg', 'Mycroft Holmes', 'Josef Myslivecek', 'Rob Reiner', 'Martin Guerregrænseoverskridende', 'Water Wizz', 'Mario']
# Processing batch: ['Cotillards Macbeth', 'Greg', 'Moises Arias', 'Haenels', 'Mille Dinesens Eva', 'Arthy', 'propper', 'Anna Paquin', 'Cooper Koch', 'Lee Alexander McQueen']
# Processing batch: ['Mike Colter', 'Toni Erdmanner', 'Laniers', 'Ole', 'Laura Madsen', 'Disney-Star Wars', 'Carla Gugino', 'Anders Walter', 'Jesus Christ', 'Maggie Peren']
# Processing batch: ['Producer George Martin', 'Michael McKean', 'Rødhales', 'Loud', 'Peter Flinths', 'Ben Stiller Stiller', 'Guangzhou', 'Am Ruther', 'udviklerAll Inclusivesig', 'Little Broomstickfra']
# Processing batch: ['Exodus', 'Accra', 'Mack Bayda', 'Frank Sinatra', 'Social Dilemmagør', 'Hotelundervejs', 'Christopher NolansDunkirk', 'Tom Hayden', 'Dr. Mantleray', 'Antarktis']
# Processing batch: ['Øystein Karlsen', 'Keisha Tillis', 'Anders Skov', 'Netflix-dokumentarenThe Witnesset', 'Vierhistorien', 'stoisk fisker', 'Powley', 'Allen Leech', 'Lundgreen', 'Broadway']
# Processing batch: ['Elpidia Carrillo', 'Keisha Lance Bottoms', 'Yonkers', 'Lars Thiesgaard', 'Kōji Yakusho', 'Kompositionsprincippet', 'Johnny Cash', 'Kristoffer', 'Gitte Hænning', 'Robert Richardsons']
# Processing batch: ['Walt Becker', 'endOne Chance', 'Carl Th. DreyersOrdetog Lars', 'Hovedperson Cady', 'Labor Dayfortælles', 'Norma', 'Emilie Mengs', 'Olga', 'juryens specialpris', 'Karl Lagerfelds']
# Processing batch: ['Kurt Vonnegut', 'Gammelfar', 'Mohammed', 'James Garner', 'Abra', 'Alysias', 'Harrison Feldman', 'Anns mors', 'Saddam Husseinkan', 'Vatnajökull']
# Processing batch: ['Eleanor Roosevelt', 'Marie Breyens dokumentarfilmNiels', 'Trevors', 'Ready Player Oneforegår', 'Hans Henrik Lerfeldt', 'Kristian Sejrbo Lidegaards', 'Mugge', 'Xavier Giannolis', 'Kazims', 'Canadas']
# Processing batch: ['Brian Enos', 'Katey Sagal', 'universitetsbys', 'Ilyas Salman', 'Walesa', 'Kate Beckinsale', 'Sveriges Oscar-kandidat', 'Anders Albjerg Kristiansens', 'Kristian Corfixens', 'Tony Todd']
# Processing batch: ['Moll', 'Evig', 'Rote Kapelle', 'Cecil B. DeMilles', 'Zamperinis', 'Dagmars', 'Beginners', 'Virgina Madsen', 'Patrick Bateman', 'Tom Ainsley']
# Processing batch: ['Wendy Hillers', 'Tom Waits-maner', 'Charlotte Brodthagen', 'Pooping Tomog', 'Paris Hilton', 'Ryslinge Højskole', 'Hans Weingartner', 'Hannah fraGirls', 'Eric Dumonts', 'Mariager']
# Processing batch: ['Scarlett Johanssons Jess', 'Loppen', 'Havana Segrand', 'per halve', 'Cáit', 'Jonas Dassler', 'Karoline Lyngbye', 'Harrisons', 'Many Saints of Newarkleverer', 'Four']
# Processing batch: ['A.M. Shines', 'Van Sant', 'Cooper Raiffs', 'Linda Blair', 'Jesper Skaaning', 'musicalAnnette', 'Peter Asmussen', 'James Baldwins', 'iRocky- ogCreed\xad-franchisen', 'Amandas']
# Processing batch: ['Georg Friedrich', 'Lau Lauritzens', 'Joanna Rakoffs', 'Émilie', 'Natasha Romanoff', 'Susanne Juhász', 'Janns', 'Susanne Storm', 'Toby Kebbells', 'medJurassic World']
# Processing batch: ['Danny McBride', 'Jussi Adler-Olsens', 'Daniel B. Sørensen', 'Ellie', 'Kim Kliver', 'Malagueña', 'Regnar Lodbrogs', 'Velardes', 'Brian Tyree Henry', 'Stratos']
# Processing batch: ['Back', 'Mini Cooper', 'Jonny', 'César', 'Johnny Reimar', 'erTwin Peaksstadig', 'Trine Piil', 'Mørke', 'Catherine Hardwicke', 'Andrej Wajda']
# Processing batch: ['Gred Kinnear', '#MeToo-feministen', 'Slobodan Miloševićs', 'Nicolas Sarkozy', 'Cobra Kai', 'Julie Budtz Sørensen', 'Dr. Kulinda', 'Gæstgiveren', 'Awesta Rogh', 'Jean de Carrouges']
# Processing batch: ['Peter Morgans', 'Volny', 'Martin Ginsburg', 'Hydra', 'Goltzius', 'Mathias', 'Onog', 'Tutankhamon', 'Alissa Wilkinson', 'Christoffer Guldbrandsen']
# Processing batch: ['fraThe Assassins', 'Martin Barnewitz', 'Bali', 'Justice Forever', 'Uliks Fehmiu', 'Søgningen', 'Lisa Kudrow', 'Nan Goldin', 'Mfra', 'Jungledyret HugoogBennys']
# Processing batch: ['Iqbal Farooq', 'Syllas Tzoumerkas', 'Gummifabrik', 'James Cordon', 'Richard Rorty', 'Olivier Nakache', 'Thomas VinterbergsJagten', 'Jays', 'Bertrand Bonello', 'Richard Claus']
# Processing batch: ['John Reinke', 'Mavericks', 'Damian', 'Hushjælpen', 'Welter', 'Paul Bowles', 'Talitha Bateman', 'Jacob Møller', 'Twentieth', 'Bondo']
# Processing batch: ['Villa Bravo', 'Byg-Fabritius', 'MedTwin Peaksdemonstrerede David Lynch & co', 'Bronsons', 'Nat', 'Ray Fisher', 'Henrik Bjelland', 'Call Saulvar', 'Munks', 'Martin Munchs']
# Processing batch: ['Majdanek', 'Got Talentganske', 'Mark Twain-historie', 'Comes Homeer', 'Giacomo Ferrara', 'Chabrol-manér', 'Albertos', 'Tremblays', 'Morten Højgaard', 'Boba']
# Processing batch: ['Ilfenesh Hadera', 'Tom Kingsley', 'afHigh Fidelity', 'Martin Bourboulon', 'Michael Hutchencekommer', 'Chaufføren Khadir', 'Cinderella', 'John Hunt', 'Ramy', 'Exquisite Pain']
# Processing batch: ['Streep', 'Signorita', 'Joel Cohen', 'IIn Brugesleger', 'Corentin Monnier', 'FraThe Matrix', 'John Musker', 'Sofia Coppolas', 'Ryan Atwod', 'Edgardo Mortara']
# Processing batch: ['Van Allen', 'Lindeburgs', 'Carl Weathers', 'Ornette Coleman', 'Historienslove', 'Chris Cooper', 'Pauline Collins', 'Annabels', 'Brie Larsons', 'Pemberton']
# Processing batch: ['No Escapeer', 'Newtons', 'Sven Wollter', 'Ferdinand', 'Ramy Youssefs', 'Mirren', 'Inge Fischer Møller', 'Hotel Ritz', 'Adler-Olsens', 'Claude Lanzmanns']
# Processing batch: ['Mancerons', 'Ratnas', 'Morjana Alaoui', 'Joachim Trier-filmeneRepriseogOslo', 'U.S.S. Nomad', 'Melody Harmony', 'Masumeh', 'Jack Klaff', 'Ivanka', 'Florence Foster Jenkins']
# Processing batch: ['Soner', 'Anja Lundqvist', 'Oscar-nomineredeCartel Land', 'Gainsbourg', 'Paola Taverna', 'Tylers', 'sydstatsmand Wayne', 'Jakob Martin Strid', 'Hørmestruper', 'Joan Fontaine']
# Processing batch: ['Pablo Larraíns', 'Midtvejskrise', 'John OliversLast Week Tonight', 'Karidja Touré', 'Erk Clausen', 'Yehezkels', 'Famous', 'Mattis Heurlin', 'Bente', 'Gretl']
# Processing batch: ['Alejandro Guzmán Alvarez', 'manStar Wars-fan', 'Jean Grey', 'Lee Chang-dong', 'Peter MorgansThe Crown', 'Lumer-Klabbers', 'Mikala Kroghs', 'Eddie Eriksson Dominguez', 'Cinema Prayerer', 'Gillian FlynnsGone Girlsolgte']
# Processing batch: ['Eve', 'Noah BaumbachsWhite Noise', 'Robert Langdon', 'Kitchen Confidential', 'Manish Dayal', 'George Floyd', 'Egon', 'Colin Farrell', 'Galeries Gourmet', 'Peter Middleton']
# Processing batch: ['David Koepp', 'Dan Kwan', 'Richard Chamberlain', 'Cecilie Lassen', 'Frémaux', 'Sjón', '/ Shit', 'All Along', 'Tom Glynn-Carney', 'Jes Dorphs']
# Processing batch: ['Joyce', 'Rachel', 'Erkan Mosque', 'Maggie Cheung', 'Terence Fisher', 'Søren Birkvads', 'Mr. Wu', 'All', 'Milana Vayntrub', 'Veronika Grønnegaards']
# Processing batch: ['Dafne Keen', 'Garfield Moviekan', 'Aspergers', 'Welles', 'Elsebeth Egholm', 'Arym Kubat', 'Jean-Philippe Vine', 'stuntsene', 'Juhl', 'Susanne Biers']
# Processing batch: ['Marc Jacobs', 'James Rolleston', 'James Ponsoldt', 'of NoneogPose', 'Assanges', 'Joe Castleman', 'Altings', 'Jakob Ejersbos', 'Stella Goldschlag', 'Quiet Ones']
# Processing batch: ['Double Happiness', 'Seth Rogens', 'Mortytil Charlie Kaufmans eksistentialistiskeAnomalisa', 'Beanie Feldstein', 'Hendricks', 'ex-narkomanen Nicky', 'John Browns', 'Teddy McDonald', 'Mädchen', 'Bradley Freegard']
# Processing batch: ['Livelys', 'John Gallagher Jr.', 'Woody', 'formår Elvira', 'Benjamin Netanyahu', 'Capote', 'Mathias Heise', 'Eric Lartigau', 'Paul King brugerPaddingtonog', 'William Gibsons']
# Processing batch: ['Mikkel From', 'Century Portrait', 'Kuhn', 'Peter Madsen-agtig', 'Mike South', 'Harting', 'Conleth Hill', 'Angela Lansbury', 'Civil Warer', 'Peter Biskinds']
# Processing batch: ['Ryan Goslings', 'Pierre Bonnard', 'Sam Garbarskis', 'Kathrin Dietzel', 'Birte Schnöink', 'Görans', 'Ed Perkins', 'Audrey Hepburn', 'Kate Walsh', 'Daniel Piazzolla']
# Processing batch: ['selvbevidst væsen', 'Mariann Hansen', 'Sjostakovitj', 'pophistorie.”Dit yndlingsbands', 'Gëzim', 'James Dean-light', 'Marsmå', 'René Magritte', 'Gérald Meylan', 'Dirk Brüel']
# Processing batch: ['Peris', 'Timmy', 'Pizzolatto', 'Max Webers', 'soulet', 'Pursuitmed', 'Joshua Jackson', 'medStar Warsog', 'Krzystof Michalowicz', 'Mambrú']
# Processing batch: ['sidenNobody Knowsfra', 'Sidse Thorstholm Larsen', 'Brennan', 'Pat Kondelis', 'Agent Classified', 'Juul', 'Stråhatte', 'Manuel Dacosses', 'Otis Redding', 'Paolo Pierobon']
# Processing batch: ['Bianca Kronlöf', 'MultitalentetDaniel Denciker', 'Netflix-serienSanta Clarita Diet', 'Tommy Steele', 'Claude Verneuil', 'Zach Gilford', 'Kasia Adamik', 'Bunny', 'Michael Brown', 'Feras Fayyads']
# Processing batch: ['Haddonfield fraHalloween-franchisen', 'Mingus', 'Charles', 'Allan Karlsson', 'ADHD', 'Stålsatte Charlotte', 'MenPaddington', 'Marie Gøtzsches', 'medHalloween Killsi 2021', 'Dan Turèll']
# Processing batch: ['Katarina LundquistsForglemmegeinetop', 'Virginia Woolf', 'Nouveau Cirque', 'Antonio Pintos', 'Calvin', 'Netflix-succesenTiger King', 'Boris Karloff', 'Bermuda', 'Jim Clark', 'Candys']
# Processing batch: ['Menzel', 'Hendrik Goltzius', 'Lalo Salamanca', 'Walking Dead(2010-', 'Gloria Allred', 'H.P. Lovecraft-inspireredeAnnihilationog', 'Axel Foley', 'Mickey Cohens', 'Saint Maudsvinger', 'Torsten Skovs']
# Processing batch: ['Casselly', 'romanDune', 'Bucks', 'Sover Dolly', 'Carol', 'Sally Alexander', 'Chris Brown', 'Morten Spiegelhauer', 'Peter Quilter', 'Logans']
# Processing batch: ['Lars-Martin Sørensens', 'Ben Stiller-filmenFlirting', 'Sanne Holmgaard Christophersen', 'Mina', 'Marco', 'formår Claudel', 'Martin Gschlachts', 'Manec', 'Stephen Hawkings', 'Ophelias']
# Processing batch: ['Mias', 'Christiansborgs', 'Bardo With Timothy Leary', 'Enrico Casarosa', 'Fredrik', 'Franz Oberhauser', 'Abukar', 'Brady Jandreaus', 'Generation Wealther', 'Gina Rodriguez']
# Processing batch: ['Lindas', 'Marlon', 'Tim Buckley-koncerten', 'Victor Salazar', 'Kong Ludvig XIII', 'Autobotters', 'Barneys', 'Hans Henrik Lerfeldt),City Slang Redux', 'Bradley Whitford', 'Stuckart']
# Processing batch: ['Søster Ruth', 'Anne', 'Jack Reacherburde', 'Riddicks', 'Gloria Burgle', 'Zacks', 'Ellen Brennan', 'Lila Avilés', 'Arcels', 'Rob Corddry']
# Processing batch: ['Wallace', 'Melisa', 'Colm Meaney', 'Umut Sakarya', 'Marijana Jankovic', 'Mari', 'Renoir', 'Kyle', 'Claudia', 'Joe Tech']
# Processing batch: ['Robert Carlyle', 'Barras', 'Laura Hildebrand', 'Reichardt', 'Grindelwald', 'Vermouth', 'Lurch', 'Toby Haynes', 'Halken', 'Valorie Curry']
# Processing batch: ['André Marcon', 'skiderik Werner', 'Blake Rangers', 'Michael Manns', 'Martin Hart', 'Dean Moriarty', 'Jørgen Ravn', 'Mændenes', 'Prins Joachim', 'Hvemer William']
# Processing batch: ['Salgado', 'Josefine Stofkoper', 'Garvey', 'Ebbe Traberg', 'Mwonzora', 'Jane Tennisons', 'Bennie', 'Monia Chokri', 'Winter Soldierop', 'Poul Schlüters']
# Processing batch: ['Modsat Desdemona', 'Lars Hugorm', 'Percy Fawcett', 'Henry Hill', 'Stephen Meyers', 'Kento Nagayama', 'Maso Pescatore', 'Perle Foster', 'Creed', 'Banning']
# Processing batch: ['Disneys', 'Carl Nielsen', 'Ingrid', 'Ashwin', 'Uma Thurman', 'Amalfikyst', 'bedsteMiami', 'Edgar Wrights', 'Tim Buckleyholder', 'Rolfs']
# Processing batch: ['Henrik Rafaelsen', 'Rare Earth', 'Cha Real Smoothrammer', 'Maria', 'Mikk Mägi', 'Henry McHenry', 'Moss’', 'Nostalgiaer', 'Iran', 'Kaya Scodelario']
# Processing batch: ['Kreis', 'Avaz', 'Street', 'Malcolm Murray', 'Kozmic Blues Band', 'Simón', 'mark', 'Bernhard', 'Earl', 'Fonz’']
# Processing batch: ['P.J. Hogan', 'Jake', 'Jasmin', 'Oregon Mortensengivet', 'Martin Rauch', 'Nicholas Britells', 'Lucys', 'Got Mailog Richard LinklatersDazed', 'Matt Furies', 'Pernille Rose Grønkjær']
# Processing batch: ['Walk Like', 'Martin Brygmanns', 'Antoni Gaudí', 'dokumentarenAquerella', 'Iver Iversen', 'Nikolaj Scherfig', 'Bernard Herrmann-agtigt', 'Elle Woods', 'Petrunyaer', 'Mike Gioulakis']
# Processing batch: ['albummetExodus', 'Jim Strouses', 'IPenny Dreadful', 'Marlene Dietrich', 'Tommy James', 'Greg Wise', 'Jacques', 'Selina', 'Björn Borg', 'Doll']
# Processing batch: ['Mads Wille', 'Louis', 'Levan Akin', 'Henrik Lykkegaard', 'Kevin Powers romanBad', 'Woodrugh', 'Tim Ballards', 'HairsprayogPink Flamingos', 'Bobby Robson', 'Ovidie']
# Processing batch: ['Ana', 'Puzo', 'Kariluoto', 'Stig Pedersen', 'Axel Bøyum', 'Piers', 'Manks', 'Stefan Jaworski', 'Animal Planet', 'Portisheads']
# Processing batch: ['Joel Karsberg', 'Mike Myers', 'Apocalypse Nowvar', 'Nanna Westh', 'Lally Hicks', 'Tom Yates', 'Moder Miriam', 'Margherita', 'Messina', 'Zachary Quinto']
# Processing batch: ['Liu Xuans', 'Weronika', 'Chris Sanders', 'Mehdi A.G. Mohamed', 'Mary Lynn Rajskub', 'atThe Voicesalligevel', 'La Mancha', 'Corsagefølger Elisabeth', 'World', 'Clooney']
# Processing batch: ['Kenneth Bøgh Andersen', 'Alan Yang', 'David Austin', 'Joannas mand Alistair', 'Asif Kapadia', 'Clara Dessau', 'Alan Menken', 'Hagai Levis', 'Rob Lowe', 'Regan']
# Processing batch: ['Irenas', 'Armin Mueller-Stahl', 'Flying Lotus', 'Elm Street', 'Robert Elswith', 'Jackson Browne', 'afTea Lindeburg', 'Janus Rasmussens', 'Guy Gagné', 'Klaus Kinski']
# Processing batch: ['Prins Charles', 'Juliette Binoches', 'Peluchonneau', 'iSouvenir', 'Michael Caines London-gangster Jack Carter', 'Regina Fjendbo', 'James Bennet', 'Greta Gerwigs', 'Brodie', 'Peter Capaldi']
# Processing batch: ['Gabe Plotkin', 'Enzos', 'Saddam Husseinen', 'Elizabeth Bergers', 'Kristian Corfixen', 'Sawyer', 'Macduffs', 'Hollywood-glatte instruktion', 'Kiris', 'Godwin Baxter']
# Processing batch: ['Benedettas', 'Whitlock', 'Cedric Myton', 'Morten Messerschmidt', 'AnnoncePolitikeren Martin Nordahl', 'Ole Munch', 'Maya Albanas', 'Johan Haugerud', 'Oscar Dyekjær Gieses', 'Oklahomas']
# Processing batch: ['LeDus', 'Katerina', '#NeverAgain-bevægelsen', 'Tango', 'Jason Sudeikis', 'Sophies', 'Means Girlsfra 2004', 'Dan Mazer', 'Escalante', 'Rafael Edholm']
# Processing batch: ['Vinci', 'Joakim', 'Miles', 'Nela', 'Brynas', 'Bahs', 'Centre Pompidou', 'Expo', 'Jørgen Moe', 'Fargo']
# Processing batch: ['Hill', 'Karo Kurrani', 'Jødiske Kulturforbund', 'Kong Ødipus', 'Milwaukee', 'Jørgen Berthelsens Minde', 'Jeffrey Dahmer', 'Psykiateren Rose Cutter', 'Kian Rosenberg Larsson', 'Evil Corp-medarbejderen Angela Moss']
# Processing batch: ['Samantha', 'E.', 'Byders', 'Michael NoersPapillonvaren', 'Winbury', 'iChaos Walking', 'Lucas Lomholt Eriksen', 'Ilena', 'Madison Iseman', 'Atalanta']
# Processing batch: ['Algernon Edwards', 'Story 3.', 'Dark Woods', 'Anders Manley', 'Kaspar Munk', 'Gary Ross fraThe Hunger GamesogSeabiscut', 'Montague', 'Kong Erik', 'Gillian Flynn', 'Richard Roper']
# Processing batch: ['Muds', 'Jimi Hendrix', 'Kærlighedens', 'Marcy', 'Catherines', 'Shargawi', 'MenMumifars', 'Robbie Weirdicht', 'Tupacs', 'Schlüter']
# Processing batch: ['Anthony Lamb', 'Kali Reis', 'Henrik Stangerup', 'Privatvideoer', 'Hatidze', 'Andrew Droz Palermo', 'Jean-Marc Fabre', '#MeToo-høtyve', 'Winnipeg', 'David Miscavige']
# Processing batch: ['Aftenens', 'Flemming Povlsen', 'Waves', 'Colbert Reporttiltræder', 'J.A. Bayona', 'Bierlich', 'Barbies', 'Jimmy Helms', 'Pauline Chalamet', 'Samanou Acheche Sahlstrøm']
# Processing batch: ['Dan Gill', 'Julekalender', 'Zadie', 'Issa Rae', 'Sorkin', 'Ladjane', 'Svupsen', 'Dannemorasynes', 'Will Scarlet', 'Madison']
# Processing batch: ['Leila George', 'Bart Layton', 'Tarokafvikles', 'formår Vinterberg', 'Monkeysvar', 'Mr. Pickles', 'Christian Dyekjær', 'Army Mankonstant', 'Sirpa', 'Jackie Kennedys']
# Processing batch: ['Bjarnis', 'Kids + Money', 'Biljana Stojkoska', 'Last Sheltertil', 'Nemo Schiffmann', 'titel(1996', 'Rafelson', 'Morten Korch', 'Blågårdsgadens', 'Sal Paradise']
# Processing batch: ['Abeer', 'Larssons', 'Bjerre Larsen', 'Ewen Montagus', 'Heathers', 'Marianne Jean-Baptiste', 'Charlie Brooker', 'Marilyn Burns', 'Basil Rathbone-klassikeren', 'Abuela Claudia']
# Processing batch: ['Carolyn Bryant', 'Frank Crichlow', 'Catching Firevar Katniss', 'Napoleon', 'Scott Cooper', 'Harvey Weinstein-skandalen', 'Franz Heinrich Kaufmann', 'Christian Arhoff', 'Gauff', 'Campbell Bower']
# Processing batch: ['Jimmy Thunlind', 'Bill Kirstein', 'Soul', 'serveretJerry Maguire-replikken', 'Strids', 'afErik Clausen', 'Zidane', 'Linnemann', 'Nora Øland', 'Klaus Riskær']
# Processing batch: ['Ally', 'Eisenhower', 'Productions', 'Katrine Marie Seidelin', 'Anouk Aimée', 'Dorte W. Høgh', 'John McClane-præstation', 'Hushpuppys', 'Amy Brennemans', 'Greg OlsonsBeautiful Darkog Dennis LimsThe']
# Processing batch: ['Hans Gruber-pendant', 'Nicholas Braun', 'Adjø Nanna', 'Gid Woody', 'Paolo Genovese', 'Billie Holidays', 'Kiss Bang Bang', 'Jeppe', 'Jenle Hallunds', 'Wild Pork']
# Processing batch: ['Ever Happysluttede', 'Valhalla', 'Benny Andersen', 'Pierrot', 'Eric Elmosnino', 'Morning', 'Millys', 'Brian Kirk', 'Addictspæder Peggys', 'Terry Stacey']
# Processing batch: ['Anders Østergaard', 'Jesse Helms', 'Ken Leung', 'Marc Webb', 'Maliks', 'Player Onesom', 'William Gibson', 'Steven Moffat', 'Williams', 'Martin Behnke']
# Processing batch: ['Boots Riley', 'Jane Krakowski', 'Mia Lyhne', 'Inger Johanne Vik', 'Josie Rourke', 'Five Years', 'Lenora', 'Guslagie Malanda', 'Elsebeth Steentoft', 'Rikke Andersen']
# Processing batch: ['Basse', 'Ella Bella Bingo', 'Jesse Garcia', 'Peter Viskinde', 'Daniel Wu', 'atReaching', 'Depp', 'Irvine', 'Jeffrey Blitz', 'Lea Blaaberg']
# Processing batch: ['John Trump', 'Henry Gayden', 'medTwin Peaksi', 'Salerno', 'Konni', 'Airletter', 'Poul', 'Dominic Savage', 'Greece', 'Josh Singer']
# Processing batch: ['Night', 'Paul Mazurskys', 'Direct Cinema', 'Other Woman', 'Karim Aïnouz', 'Penns', 'Foxx', 'Henriette Laursen', 'Jina Mahsa Amini', 'Helle RyslingesSirupfra']
# Processing batch: ['J.B. Frøet', 'Jeppe Gjervig Gram', 'Adam Nielsen', 'Lasse Barkfors', 'Martin Rohde', 'Franz Kafka', 'Günter', 'John Cleeses', 'Jared Letos', 'Pedro Costas']
# Processing batch: ['Shepherdpå Ekko Shortlist', 'Ghiblis', 'Eyes Closed', 'Axel Byvang', 'Louis Wain', 'Florlette', 'Johannes Lilleøre', 'Æresbodil', 'Kimberley Motley', 'Shaw']
# Processing batch: ['Classici Award', 'Karins', 'Nawi', 'Christian De Sica', 'Maja Malou Lyses', 'Takehiko Inoue', 'Kellys', 'Douglas Gordon', 'Hazels', 'bramfri']
# Processing batch: ['Ramon', 'Leif Panduros', 'Buyers Club', 'Joe Techs', 'Chris Hedges', 'Lizzy Caplans', 'Xavier Gens', 'Patrik', 'Anders Hemmingsen', 'Anna Thygesen']
# Processing batch: ['Thomas Porsager', 'Agnetha', 'Cirkelmodellen', 'Jack Torrance', 'Victor Stone/Cyborg', 'Sterling Morrison', 'Miyu Sasaki', 'Patrick Zweig', 'Maggie Smiths', 'Jomfru Maria']
# Processing batch: ['Gatsbys', 'Quim Gutiérrez', 'Camerons', 'Casper Belmaatis', 'James Grays', 'Frank Langella', 'Roma', 'Lisbeth Wulffs', 'Marvel-serieWandaVision', 'Mussolinis']
# Processing batch: ['Eladio', 'Glenn Howerton', 'Daniel', 'Obert', 'David Wolstencroft', 'Frank Senior', 'Frederik Rye', 'Ricky Gervais', 'Rick Deckard', 'Meryl Streeps']
# Processing batch: ['Tetsuro Kodama', 'Uma Thurmans', 'Michelangelo', 'Patrick Ness', 'Anna Halberg', 'Dreami', 'Old Mener', 'Rooney Mara', 'Kerima', 'Soderbergh']
# Processing batch: ['Rottmayer', 'Karakteren André', 'Patrick Berdino', 'Poul Bang', 'Jack Black-filmenGåsehud', 'Ethan Coen', 'Madame Blanc', 'Quinn', 'Trubadurix', 'Njenna']
# Processing batch: ['Larry ClarksKids', 'Kong Ade', 'John SteinbecksVredens', '#6i 2008', 'Asbæk', 'Benjamin Wandschneider', 'Franz Biberkopf', 'Days LaterogAnnihilation', 'joints i', 'Austes']
# Processing batch: ['David Jenkins', 'Nicolai Dahl Hamilton', 'Carpenters', 'Andrej A. Tarkovskij', 'Klichés', 'Loachs', 'MedFamilien Julhar', 'Beau', 'Jaques Renoir', 'Cliffs']
# Processing batch: ['Tim Wardle', 'Fabiola', 'tom park', 'Bell', 'Lively', 'Usual Suspects', 'News', 'Jakob Ejersbo', 'Conway', 'Kenneth Carlsen']
# Processing batch: ['Anna Stokholm', 'Sam Brenner', 'Iben Maria Zeuthen', 'Colonizeder', 'Mary Louise', 'Enterprises', 'Dominic Kearney', 'Graciela', 'Casper Rieper-Holm', 'Luke Grimes']
# Processing batch: ['Sherlock Holmes', 'Hayao Miyazaki', 'Emilie Molsted', 'Brit', 'Jason Blum', 'Øystein Dolmen', 'Motherfuck', 'Amatuers', 'Harry Potter-filmene', 'Buddy Duress']
# Processing batch: ['Bill Tench', 'Kate Upton', 'Clubfår', 'Edith Piaf', 'Simon Kaijser', 'Jacob Haugaard', 'Carlos', 'Alex Pritz', 'Milan stoisk', 'Brian Gleeson']
# Processing batch: ['Kenny', 'Tova Mozards udstillingILoveRuss', 'Porn Valleytilbyder', 'MenFabian', 'Niels Jerl', 'Bush', 'Eva MulvadsLove Child', 'Pedro Almodóvar', 'Mon Mothma', 'atScandinavian Starikke']
# Processing batch: ['Mattias Nordkvist', 'Niklas', 'Kurt Sutter', 'Heroer', 'James Hansen', 'Eton', 'Rupert Evans', 'H.', 'Terry Gilliams Hunter S.', 'Katherine Langford']
# Processing batch: ['Guitaristen Thomas', 'Funki', 'Murmur Film', 'Laura Donnelly', 'Ben Fransham', 'Remorseen', 'Burton', 'Kyle McLachlan', 'Murakami', 'Stede']
# Processing batch: ['Stevenson', 'Nils Thorsens biografiGeniet', 'Craig Cobb', 'Bodies Bodiespirmært', 'Abel', 'Aidas', 'Desiree', 'Amir Ebrahimi', 'Good Americaner', 'Michael Douglas’ Gordon Gekko']
# Processing batch: ['Mosuls', 'Musicals', 'Jacobi Jupe', 'Eggers', 'John Woo', 'Christy Garlands', 'Gravers', 'Luke Davies', 'Matt Whiteleys', 'Mortag Freund']
# Processing batch: ['Kodakfilm', 'Matthew McConaugheys', 'Tove Kurtzweil', 'Charles Perrault', 'Jonas Holst Schmidt', 'Lange', 'Ronnie Petersontil', 'Ghislaine Maxwell', 'Demi Moore', 'shtetl kitsch']
# Processing batch: ['Ian Fleming', 'Isao Takahata', 'Rayna Boyanov', 'Libanons', 'Orbán', 'Madelineon', 'Macchio', 'Jiangyan Wang', 'Rasmus Heide', 'Jaegers']
# Processing batch: ['Hortenses', 'Jeanne Dielmaner', 'Robert Shapiro', 'Miangaly', 'Erlend E. Mo', 'Amira Casar', 'John Lennon', 'Myselfer', 'Severins', 'Amy Winehouses']
# Processing batch: ['Cher', 'John Procaccino', 'somStyrmand Karlsen(1958', 'Rose iDownton Abbey', 'Mendelsohn', 'Haakon', 'Martha Mitchell', 'Susan Sarandon', 'Blakes', 'Kiss Bang BangogTerriers']
# Processing batch: ['Xavier Beauvois’Jagten', 'Kong Ghezo', 'Michael Jai White', 'Ruth Ramos', 'Månekongen', 'Jennifer Vedsted Christiansen', 'Nate', 'Yves Capes', 'Adam Pålsson', 'Amat Escalantes']
# Processing batch: ['Auguste Rodin', 'Berit Madsen', 'Jerry', 'Christina Aistrup Hansens', 'strømmerIn', 'George Romero', 'Ben Stassen', 'Eva Selsing', 'Emmett J. Scanlan', 'Joseph Kosinski']
# Processing batch: ['Point', 'Dostum', 'Christian Dior', 'Harold Lauter', 'Embryo', 'Melodi Grand Prix', 'Coin', 'Diggy', 'Social Psychology of Helping', 'Helen Mirrren']
# Processing batch: ['Thomas W. Gabrielsson', 'Dan O’Bannon', 'tilMasterchefpå TV3', 'Noah', 'Pulcinella', 'Asmita', 'Eva Hess Thaysen', 'Lena', 'Henning Valin', 'Jørgensens']
# Processing batch: ['Taxi', 'Raymond Enoksens', 'lillebrors', 'Lynda Rutledges', 'Mikkel Okholm', 'Jedier', 'Auguste Renoir', 'Stram Kurs', 'Henrik Sandberg', 'Leans']
# Processing batch: ['Zhora', 'Paul Getty', 'Jean-François Tosti', 'Calamity Janes', 'John Guleserians', 'Nato\xadpartneren USA', 'René Dif', 'Iqbals', 'Tordenskjolds', 'Jack McClane']
# Processing batch: ['Jim Gaffigan', 'Marie Kondo', 'Conjuring', 'Marvel-sammenkoblingAvengers', 'Muhammeds', 'Journalist Kristian Linnemann', 'Kidane', 'Jan Gehlaltidret', 'Pippa Ehrlich', 'Surmule']
# Processing batch: ['Isabela Ferrer', 'Ashleighs', 'Shades', 'Reynir', 'Mille Dinesen', 'Mackenzie MacHale', 'Michael Sherman', 'Emma Watson', 'Huntsman', 'Magueritte']
# Processing batch: ['Danielhar', 'Jason', 'Orange County', 'West Papua Highlands', 'Ostias', 'Andrew Haighs miniserieThe North Water', 'Whites', 'Guardians of the Children', 'Netflix-filmenHillbilly Elegy', 'Peter Engels']
# Processing batch: ['Erik Selvig', 'Trudys', 'Huma Abedin', 'Shakira', 'Albert Stark', 'gud Atlas', 'Dominic Cooke', 'Erik Petris', 'High Wateren', 'MacFarlane-fans']
# Processing batch: ['Elevenog Christopher Nolans', 'Lawrence D. Cohens', 'Ben Kingsley', 'Henning CarlsensKlabautermandenfra', 'C. B. Henriques', 'John Madsen', 'Nanna Bisp Bücherts', 'Holmes', 'Julie Delpys komediedrama2', 'Jelena Kordic Kuret']
# Processing batch: ['Michael Beach Nichols', 'Jon Favreau', 'Band-Aid Nose Man', 'George V. Higgins', 'Mr. Chocolate', 'Pilmark', 'Maya Gonzalez', 'Heister', 'Fader Callahan', 'Bill Cosby']
# Processing batch: ['Abel Gances', 'Lennart Bergelin', 'Hatfield House', 'Hero Academia', 'Sun Tzus', 'Ove Sprogø', 'Mr. Mercedeser', 'Rævs', 'Yves Saint Laurents', 'Ryan Fleck']
# Processing batch: ['Erebor', 'Menig Cole', 'Joseph Palmer', 'Paprika Steen', 'Headeys', 'Guy RitchiesSherlock', 'Murens', 'Marie Østerbyes', 'Say Neverom Biebers', 'Otto Leisner']
# Processing batch: ['Cassandra Clares', 'Barolo', 'Tony Revolori', 'Libertas', 'Sam Rockwell', 'Evelyn Abbott', 'Amalie Dollerups', 'Bobi Wine', 'Saga Norén', 'Eric Khoo']
# Processing batch: ['Cindy Shermans', 'Priklopil', 'Shirley MacLaine', 'Genève', 'Liam Hennessy', 'Erich', 'Michael Madsens', 'Tom Blyth', 'Hans Zimmer', 'Glinda']
# Processing batch: ['Susan Sontag', 'Andrey Konchalovsky', 'Katherine', 'Tris', 'Dominic', 'atBlue Beetleer', 'Daniel Craigs', 'Avi Issacharoff', 'Anthony Bourdain', 'Your Enthusiasm']
# Processing batch: ['David Borensteins', 'Mani', 'Phie Ambos', 'Jens Gaardbo', 'Lithgows Ailes', 'Ralph Fiennes', 'Jimmy Smits', 'Dianne Dwyer Modestini', 'Coco Pops', 'Becky']
# Processing batch: ['Jonathan Glazer', 'Luke Kleintank', 'Line Knutzon', 'Dynamite', 'Skal Alice', 'Eske Willerslev', 'Onkel Anders', 'Magnus', 'Loznitsas', 'Caspar Leinen']
# Processing batch: ['Harris Dickinson', 'Pidgey', 'Belsons', 'Antonio Banderas-imitator', 'Thread', 'Rosario Dawson', 'Karl', 'overBreaking Bad', 'James Cole', 'Rapunsel']
# Processing batch: ['Roland Joffé', 'Muriel Donnelly', 'Fancy Danceer', 'Oberst Kurtz', 'Mark Ronsons', 'Statesman', 'Hannah Elbke', 'Lord Byron', 'Good Lucker', 'Annie Machon']
# Processing batch: ['Jerry Butinger', 'Thoreau', 'Agent Fiks', 'Derek Haysom', 'Ian Dury-dokumentarenSex & Drugs & Rock & RollogVejen', 'Chimagår', 'Jacob stolt', 'Seks', 'Hansen', 'Jane Austensk']
# Processing batch: ['Jan Harsem', 'Joe bemærke', 'Generation KillogShow', 'Joe Mantegna', 'Richard Gadds', 'Ramona Macho', 'Jonas Ussings kortfilmZombiehagen', 'Tony Blairs', 'Madueño', 'Alanté Kavaïté']
# Processing batch: ['Twin Peaksmed', 'Art Garfunkel', 'Exits', 'Ingeborg', 'Mellie', 'Herschel', 'Riot Cluber', 'Anjaans', 'Kristoffer Borgli', 'Patricia Arquette']
# Processing batch: ['Hunter', 'Hannes Holm', 'Dusty Markhopper', 'Trigórin iMågen', 'Madeleine', 'Lorenzo Woodroses', 'Jomfru Maria-statuette', 'Allans', 'Aslans', 'Cloverfield Laneer']
# Processing batch: ['Joe and The Juice', 'Giovanni Manzoni', 'Scenariorammer', 'Daniel Davies', 'Anders BreinholtsNatholdetpå', 'Scamander', 'Wheatleys', 'Hannibal Buress', 'White Walker', 'Michael Morris']
# Processing batch: ['Jake Sully', 'Beths', 'Pamela Andersons', 'Jennifer Fox', 'Les Misérablesudspiller', 'Ryszard Lenczewski', 'Stig Rossen', 'Hemsworth', 'Ilenas', 'Outog']
# Processing batch: ['Agnès Jaoui', 'iGodzilla 2', 'Vibeke', 'Mimi', 'Foie Gras Weekend', 'Collegeersådårlig', 'Lucas Kankava', 'Kongelige Bibliotek', 'Petersen', 'fraThe Wireer']
# Processing batch: ['Kane', 'Morten Hauch-Fausbøll', 'Elle Fannings', 'Melodi Grand', 'Palmemordet', 'Teslaer', 'Aphex Twin', 'Wilbur', 'Safe House', 'Paul VerhoevensBenedettaog']
# Processing batch: ['Hope', 'Tham Luang-Khun Nam Nang Non', 'Mathilde Falch', 'Jaakkos', 'Gemma Chan', 'Jake Weary', 'Charos', 'Jack Crawford', 'Martin Goldschmidt', 'Enorme']
# Processing batch: ['Marco Ramirez', 'Hitlers', 'iTel Aviv', 'Noam Chomsky', 'MedTransnistrahar den', 'Walaa', 'Barbe-Nicole', 'Wash Westmoreland', 'Louise Bergstein', 'Remy Denton']
# Processing batch: ['Peter Vack', 'Christian Potalivo', 'Sille Malou Nielsen', 'Viggo Mortensens', 'Alan Bennets', 'Eskil Vogt', 'bo', 'Kwisatz Haderach', 'Anarchyvandt', 'Emanuele Crialeses']
# Processing batch: ['Gårdejeren Fred Smith', 'Wordfik', 'Boy Ewald', 'Fontaine', 'Isaks', 'Charles Xavier', 'Jake La Motta', 'Jesse', 'Stine Bramsen', 'Anni']
# Processing batch: ['Michael Gandolfini', 'Brian Hill', 'Brunos', 'Ma Loute', 'Agustín Almodóvar', 'Højfeldt', 'Arthur Smith', 'Whitakers', 'Eras Tourer', 'Jackmans Wolverine']
# Processing batch: ['Cohns', 'Ben Bradlee', 'Derek Jacobi', 'Bess', 'Bibi Andersson', 'Sterlin Harjo', 'Joseph DeAngelo', 'Lisa Joy', 'Yakari', 'Barnards']
# Processing batch: ['Anna Todds', 'Foreversættes', 'Kasper Windings', 'Herman J. Mankiewicz', 'modthe land', 'Leisureland', 'Otto Premingers', 'Rudolf Höss', 'George VI', 'Casper Sloth']
# Processing batch: ['Aryan', 'Carson McCullers', 'Mr. Potato', 'Stricklands', 'Jens Serup', 'Matthew Lillard', 'Francis Ford Coppola', 'Nadine', 'Nora Lum', 'Robert Redfords']
# Processing batch: ['Savile', 'Huy Quan', 'Jim Balsillie', 'Rida', 'motorbrand', 'Whitehall', 'daThe Darkest Mindsgaloperer', 'P.T. Andersons', 'Cristian MungiumedKold', 'Kirsten Birgit']
# Processing batch: ['Malthe Koch', 'Krystal', 'Alfred Molina', 'Allens', 'Espen Sandbergs', 'William Wisting', 'Eminems8 Mileer', 'Mia Wasikowska Chris', 'Grazer', 'Mr. Kieslowski']
# Processing batch: ['Jan Gisseberg', 'Blue Ruiner', 'Móri', 'Peter Peter', 'Nathalie Portman', 'Lionsgate', 'Trom Cruise', 'Eats', 'Mie Schou', 'Beck Weathers']
# Processing batch: ['Bamse', 'Mamoudou Athie', 'Marlon Brando', 'Work Hard', 'Khoo', 'Toby', 'Sina', 'Christopher NolansInterstellar', 'Tyttebær-Maja', 'Trier Cannes-festivalens']
# Processing batch: ['Doms', 'formår Kutcher', 'såsomBerlin StationogSuburra', 'Sagen Colliniudspiller', 'Stephanie Allain', 'Ritardando', 'Podimo', 'Javiers', '#MeToo-indspark François Ozon', 'Alexander Vlahos']
# Processing batch: ['Teufels Badpå', 'Jødisk', 'Sonny', 'Stephen Gaghan', 'Turing', 'Bloodline', 'Zink', 'Fall Guyer', 'Rikke', 'Titans']
# Processing batch: ['Jørgen Leth', 'Mamie Gummer', 'Richard Connells', 'Joe Anders', 'Caesars', 'Niels Bohr', 'Michael Cimino', 'Henry Walker', 'Fader García', 'Escape Rooms']
# Processing batch: ['Christian Sønderby Jepsens', 'Morderen', 'Misha Meskhi', 'James Bond-wannabe', 'Greys', 'Alana Bloom', 'Rosa Salazar', 'Kontinent', 'Rocco Meats', 'Die Astas']
# Processing batch: ['Sope Dirisu', 'PeaksogForbrydelsen', 'Kaptajn Sabeltand', 'Dahl Hansen', 'Troy Anderson', 'Hirayamas', 'per sæson', 'Paul Walter Hauser', 'Pepsi', 'Morricones western-mundharmonika']
# Processing batch: ['Valerians', 'Donnie', 'Rachel Feinstein', 'Doubter', 'Daniel Denciks', 'Tilly', 'Hopes', 'Jægeren Gustavsen', 'Lucio Dalla', 'Ghanesiske Abraham Attah']
# Processing batch: ['Marina Man. Rollen', 'Jebreal', 'Judy Garland', 'Charlotte Sieling', 'Schulz', 'Rise', 'P. Henson', 'Jeff Orlowskis dokumentarThe Social Dilemmamales', 'Michael Douglas iFalling Downhar', 'Anders']
# Processing batch: ['Robert Downey Jr.', 'Osakaslår', 'Jazzens', 'Jobs', 'Rhapsodyvar', 'U.N.C.L.E.til', 'P.J. Hogans', 'Maria Tórgarð', 'Doug Liman', 'Boyle']
# Processing batch: ['Embryoer', 'Lejemorderen Santino', 'Bostons', 'Charles Addams', 'Issas', 'Tove Maës', 'Mildred', 'Jeannette', 'Thomas VinterbergsJagtenen', 'Berchtold']
# Processing batch: ['Noiaer Camilla Ramonns', 'Hoytema', 'Blumberg', 'Marie Bregendahl', 'Rob Sprackling', 'Krutov', 'Egos', 'Adrian Lloyd Hughes', 'Lovers Left Alive', 'Neal Gamby']
# Processing batch: ['James Matthew Barrie', 'Daniella Riva', 'Anne Blomsgaard', 'Gene Kelly-musical', 'Patrick Robinson', 'Brian Patterson', 'Julie Delphys Celine iBefore', 'Village People', 'Metin', 'Eduard Schnedler-Sørensen']
# Processing batch: ['Jeff Dupres', 'Carl Orffs', 'Landsbyhoren', 'Mads Malik Grosos', 'Andrea Scarduzio', 'Ghibli', 'Matthew Macfadyen', 'Salomons', 'Kimmys', 'James Stewart']
# Processing batch: ['Annemarie Schwarzenbachs', 'Jun. Størstedelen', 'Carsten Bjørnlunds', 'Anemone Camphausen', 'Dumbo', 'A-Hao', 'Nicholas Alexander Chavez', 'Joe Wrights', 'Søren Peter Langkjær Bojsens Super', 'Bullocks']
# Processing batch: ['tværfilmisk', 'Antonio Bolivar', 'Nicholas Meyer', 'Romeos', 'Holms', 'Aske', 'Shanghai Knights', 'Jesper Bank', 'Troels Unneland', 'Yonas']
# Processing batch: ['Samanou Acheche Sahlstrøms', 'Simon Kvamm', 'Giggle McDimples', 'Guldløve-vinderenRomakun', 'dronning Marie Antoinettes', 'Julian Jarrolds', 'spillefilmdebuten10', 'Wendy Byrde', 'Benjamin Moslis', 'Stenberg']
# Processing batch: ['Hogwarts', 'Tage Erlanders', 'Lina', 'Metins', 'Michaelgroomedesine', 'Gwendolyn', 'Fu Panda-instruktøren Mark Osborne', 'Bekhti', 'Anjaan', 'Kristina Kovacs']
# Processing batch: ["Jean d'Ormesson", 'Maurice Leblancs', 'Jeanette Dzienis', 'Rossellini', 'Alfred Larsen', 'Little Galaxies', 'Fincher', 'Kristoffer Bech', 'Finanshajen', 'Eyjafjallajökull']
# Processing batch: ['Torfinnur Jákupssons', 'Elvis', 'Cronhammars', 'Erling Jepsens', 'Jenny Slate', 'Edward Nortons', 'Thales Cavalcanti', 'Lina Lambæk', 'Nicholas Galitzine', 'Carla']
# Processing batch: ['Matt Smith', 'Guldbrandsen', 'Dylan McDermott', 'Uffe', 'Gro Svendsen', 'Arne', 'GøgeredenellerShutter Island', 'Nolas', 'Juno Temple', 'Brad Peyton']
# Processing batch: ['Lisa Nilsson', 'Leonora', 'Bertie Carvel', 'Daisy Ridley', 'Sven Stolpe', 'Nucleus', 'Gene Kelly', 'Jurnee Smollett-Bell', 'Dominic Ongwen', 'Suzette Gemzøes']
# Processing batch: ['Anders Refns', 'Robert F. Kennedy', 'Jaime Vadell', 'More', 'Tahar Rahim', 'Cillian Murphys', 'Zach Creggers', 'Madison Wolfe', 'Stieg Larsson', 'Ender Mildred Ratched']
# Processing batch: ['Anne Claire', 'kong Zeus', 'Fikret', 'Ruth & Alexer', 'Sommai', 'Olof Palme', 'Jared Bush', 'Anja Lundquist', 'Karla Sommer', 'Luciano Pavarotti']
# Processing batch: ['Pete Koslow', 'tilOmblines', 'Arthur Kemper', 'Lærke Sanderhoff', 'Axe Capital', 'Amira', 'LipnackKuehls', 'Sebastian Bull', 'Martin Jensen', 'Anna Rose Holmer']
# Processing batch: ['Flintstonehar', 'Bernhard Kellers', 'fraCharlie’', 'Malmqvist', 'Kaur', 'medMarie Antoinette', 'Joe Carnahan', 'Thanos', 'Atlantic Records', 'Symbolik']
# Processing batch: ['Jeffrey Hunter', 'François', 'Ash', 'Sally Potter', 'Alice Isaaz', 'Korsbæk', 'Niels Krause-Kjærs', 'Arne Grønbæk', 'Killerfik', 'Parkers']
# Processing batch: ['Brüggers', 'Henrik Day Poulsen', 'Greta Garbo', 'Burrys', 'atThe French Dispatchikke', 'Get Downud', 'Tage Nielsen', 'Bobbitt', 'andetA Place Called Lloyd', 'Garth Ennis']
# Processing batch: ['Omerer', 'Mary Harron', 'Bernard Sumner', 'Rose Byrne', 'Jean-Louis Trintignant', 'Mariana Treviño', 'Maxine', 'Sonos', 'MacKay', 'Ekko Shortlist-filmThy']
# Processing batch: ['Tina Fey', 'Eileen', 'Kevin Feige', 'Poul Henningsens', 'Atelier Animation', 'Ray King', 'Kevin SmithsClerks', 'Errol Morris’The Thin Blue Linefra', 'Stephen Hawking iTeorien', 'Søren Birkvad']
# Processing batch: ['Crime Scene', 'Generation', 'Higelin', 'Kylie Minouge', 'Bonnie Piesse', 'Sensei(1971-77', 'Raped', 'Christophe Honorés', 'Mathis Hammer', 'Salim']
# Processing batch: ['Anna Mee Allerslevs', 'Paul W.S. Andersons', 'Thomas Szabo', 'Charles de', 'Howard', 'Angelas', 'Aydins', 'Broby Johansen', 'Alexa Davalos', 'David Wenham']
# Processing batch: ['Maisel', 'Karl Urban', 'Holy Fucking Shit', 'Olivier Bonnaud', 'Raju', 'Præsident Franklin Roosevelt', 'Jason Reitman', 'Blue Jasmine', 'Clinton', 'Ronan']
# Processing batch: ['Ansas', 'James VI’s', 'Pers', 'Jake Szymanskis', 'Hana Jusics debutfilmI', 'JulieogForbrydelsen', 'Alana', 'Berthelsen', 'rødbrune', 'Lance Armstrong']
# Processing batch: ['Lonnie Chavis', 'Byrdes', 'Zeke Sikes', 'Roy Tillman', 'Drusse', 'Chan', 'Gusmãos', 'John Carew', 'Paul Bettany', 'David Bowie']
# Processing batch: ['Citizen Cheney', 'Alina Rudnitskayas', 'MedBig Eyes', 'Monkeypaw Productions', 'Alastair Siddons', 'Chandra', 'Marina Zenovichs', 'Bo Bilstrups', 'Hollywoods sci-fi-', 'Downtons']
# Processing batch: ['Mowglis', 'Human Scalei', 'Aaron Tayloer-Johnson', 'Joshua Rofé', 'Nickelodeon Movies', 'Imelda Marcos', 'Mark Ruffalos', 'Kendall', 'Troels Engelbrecht', 'Susannah Grants']
# Processing batch: ['slagsParadise Hoteli', 'Henrik Dahl', 'Peter Stormare', 'Rob', 'Patrick Gallagher', 'Thure Lindhardt', 'Pink Noise', 'Major Tom', 'Omer', 'Beskrivelsen']
# Processing batch: ['Ford Falcon', 'Walmart', 'Kacper Bieliks', 'Machina', 'Matthesen', 'Owen Milgrim', 'Buzz', 'Frelle Petersen', 'kanThe Covenantikke', 'George Lazenby']
# Processing batch: ['Diekendakers', 'Tony Hawk', 'Christoffer Evan Ansel', 'Piper Chapman', 'Plutarch', 'Lucy Lawless', 'Rokka', 'Rachel Bilson', 'Underground-nummerAll Tomorrows Parties', 'somEl Club']
# Processing batch: ['Belly Howle', 'Emily Taaffe', 'John Maddens', 'Sorena Sanjari', 'Juliette Binoche', 'Packard Super Eight', 'Cambodjas', 'Horses', 'Teys Schucany', 'Liz Smiths']
# Processing batch: ['Michael Noers danske milepælNordvest', 'Assers', 'David Helfgotts', 'Richard Dider', 'Jack Daniel', 'Sparrow', 'Arts', 'Saldana', 'Kidman', 'Heinrich Heines']
# Processing batch: ['Guy Pearce', 'Afrikas', 'Green Lundberg', 'Lee Konitz', 'Woody AllensManhattani', 'Tom of Finlandskildrer', 'Amleth', 'Anna Sofie Hartmann', 'MenPaper Townsrammer', 'Larry Karaszewskis']
# ...
# Processing batch: ['A. Films', 'Cynthia Erivo', 'Adam Buschard', 'Emliy Blunt', 'Furby', 'Emil Johnsen', 'Emilie Claudius Kruses', 'Meyhoffs Bronson', 'Dick Deguerin', 'Welket Bungué']
# Processing batch: ['Endless Poetry', 'Rob Hall', 'Johan Knattrup JensensSkammekrogen', 'Nana', 'Ritchies', 'Anne Hamilton-Byrnes', 'Peter Greenaways', 'PixarsInderst', 'Wonder Womanog', 'enStar']
# Processing batch: ['Craigs', 'Mortensen', 'somBonnie', 'F. Javier Gutiérrez', 'Can Demirtas', 'Judah Lewis', 'Kirsten Skyttes', 'John McLaughlin', 'afSway', 'Talefortsætter']
# Processing batch: ['Dustins', 'Cravalho', 'Asghar Farhadi', 'Bodyguarder', 'Buckingham Palace', 'Biebers', 'Niels Holck', 'Bruce Webers', 'Harrisons Fords', 'Pico Alxendander']
# Processing batch: ['Sammy Fabelman', 'Bodnias', 'påthe casting couch', 'dokumentarfilmBallerina', 'Zac Efron', 'F.P. Jac', 'Lazarescus', 'påMr', 'Clutter', 'Jack Amiel']
# Processing batch: ['Atticus', 'Leo', 'Lucinda Edwards', 'Pontoppidans', 'Hans-Michael Rehberg', 'Strawberry', 'Leo Bill', 'Jackie Hoffman', 'Jani', 'atThe Marvelous Mrs']
# Processing batch: ['Assa Rytter', 'Debra Jo Rupp', 'Cookie', 'Emilie Kroyer Koppel', 'Jack Reacherer', 'Rosemarie', 'Guðmundur Arnar Guðmundsson', 'George R. Romeros', 'Keith Maitlands', 'Serenas']
# Processing batch: ['formår Mamoru Hoseda', 'Henrik Schaefer', 'James Erskine', 'Mikael Øverlie Boukhal', 'Chris Fedak', 'Peter Pan-land', 'præste-James Bond', 'Ivana', 'Forum', 'Thoreaus Maine-skove']
# Processing batch: ['Larry ClarksBully', 'James Logan', 'John Wayne', 'Adnan', 'Ditte Giese', 'Mexicos', 'Good Nursesygdommen', 'JB Bernstein', 'Sergei Filin', 'Mikael Wiehe']
# Processing batch: ['Averys', 'Hoyte van Hoytema', 'Helle Rabøl Hansen', 'Brenda Lee', 'Terry Pratchett', 'Yann Mantel', 'Seth', 'Jesse Owens', 'Brad Dourifs', 'Marlon Moreno']
# Processing batch: ['Rubaiyat Hossains', 'Baz LuhrmannsMoulin Rouge', 'Hovedperson', 'Kim Wallpå', 'Anti-Skurke Forbundet', 'Womanvar', 'Bianca Stitger', 'Nazi', 'William Joyces', 'Prison']
# Processing batch: ['Nikki Blonsky', 'Ewen Bremmer', 'Påskehare', 'Oscar-vindendeThe Queen', 'Mamoru Hosodas', 'Kiefer Sutherland', 'Noah Hawleys', 'Alina Levshin', 'Eva Löbau', 'Lech Walesa']
# Processing batch: ['Simon Elliot', 'Paiva Pedersen', 'Gus Fring', 'Antonio Banderas', 'Netflix-serienBloodline', 'Atomic Blondeer', 'Henrik M. Dahlsbakkens kalejdoskopiskeMunch', 'Shinkansen', 'Malcolm', 'Michaël Abiteboul']
# Processing batch: ['Hader', 'Ulven Peter', 'Steve', 'Junior', 'Waffen-SS-officer', 'dystreApocalypto', 'Mogens Glistrup', 'Muhammad Ali', 'Paul Middleditch', 'Lindon']
# Processing batch: ['Christine Sønderris', 'Johan', 'ikkeLittle Women', 'Helena Rubinstein', 'Lovelessløb', 'Ville Gideon Sörman', 'Peter Bergs', 'aktivisme', 'Petzolds', 'Leonard Pine']
# Processing batch: ['Thomas Pynchons', 'Nicolas Cage-film', 'Adrians', 'Wants Some', 'Maja Jul Larsens', 'James Earl Jones', 'Alariks', 'Søren Huss', 'Anders Roslund', 'Registrering Danmark']
# Processing batch: ['George MacKay', 'Bryan Singer', 'Poul Malmkjær', 'Tony Yacenda', 'Bindslev', 'Altså', 'Sassy', 'Colettes', 'Rob Savage', 'Pigens']
# Processing batch: ['Jack Torrances', 'Michigan State University Police', 'Southern California', 'Like Mestarter', 'Kiawentiio', 'Sensory Ethnography Lab', 'Simon Rex', 'Nikki', 'AgeogMadagascar', 'Susanna Son']
# Processing batch: ['ko-kød', 'Clara Westhoff', 'Raimi', 'Selma Dali Pape', 'Bådens', 'Jang', 'Sputnik', 'portrætfilmCornelis Vresswjik', 'Earl Stone', 'Nyasha Hatendi']
# Processing batch: ['Xiao Bei', 'Cloverfield Paradox', 'Linda P.', 'Joan Cusacks', 'Anna Seghers', 'Krzysztof Kieślowskis', 'Fei Feis', 'Herman', 'Véronique', 'Krysty Wilson-Cairns']
# Processing batch: ['George Bush', 'Sam Hargrave', 'Anderssons', 'Devil Wears Pradaudkom', 'Kaouther Ben Hania', 'Ola G. Furuseth', 'Jakes', 'Kung Führer', 'Anders Villadsen', 'Svend Åge Madsen']
# Processing batch: ['Frank Olson', 'Claus Oldenburg', 'Kauffmann', 'Claudia Jessie', 'Hardin Scott', 'Gibneys', 'Chris Pines', 'Diana Rævenskjold', 'Kurtz', 'Bradley Cooper']
# Processing batch: ['Natalie Radmall-Quirke', 'Lili Elbe', 'RuPaul', 'Kollisionog', 'Jolies', 'Flora Wingraves', 'Stantons', 'Guyer komisk', 'Susanne Bier', 'Babylonsvisuelle']
# Processing batch: ['Muschietti', 'tingene ligeud', 'Grisebachs', '#33', 'Margo Martindale', 'Janine Storsky', 'Birgitte Stærmose', 'Françoise Sagan', 'Taro', 'Natasha Arthy']
# Processing batch: ['John CarpentersMaskernes', 'rendyrketPrins Valiant-skurk', 'Oren Uziel', 'Andrea Bocelli', 'Francis Lawrence', 'Malmros’', 'Hussein', 'Pepe de Lucía', 'Wills', 'Sonja Gerhardt']
# Processing batch: ['Paradisehar', 'Albrechtsen', 'Frederiksdal Kirsebærvin', 'J.J. Gittes', 'romanVilhelms', 'Rise Roar Revolt),LeoogPonniyin Selvan', 'Mads Mathiesen', 'Paolo Sorrentino', 'Mette Pedersen', 'Sundhedsfanatikeren Tassone']
# Processing batch: ['Peter Moffat', 'Misako', 'Jagnas', 'Victor Kossakovskys', 'Marie Curie', 'Emil Falkehar', 'David Letterman', 'Meg Ryan', 'Hurricane Heistfår', 'Tom Sawyer']
# Processing batch: ['Pressburger', 'Jettes', 'per se', 'Rose', 'Maybelle', 'IParanoiagår', 'Danger Ehren', 'Mirabel', 'Kreeses', 'Hasse']
# Processing batch: ['Gerhard Bauer', 'Franz', 'Carax', 'Mahalia Jackson', 'Philip Pullmans', 'Emma Bones', 'Ang Lees undervurderedeTaking Woodstockknap', 'Maisels', 'Ginevra', 'Torben Skjødt Jensen']
# Processing batch: ['Dev Patels', 'Noel', 'Jewett', 'Nicoline', 'Tómas GislasonsOvercomingplacerer Denciks', 'Taras', 'Todd Melnik', 'Jakob Bitsch', 'Oliver Assayas', 'Franklin']
# Processing batch: ['Emma Corrin', 'Linda Lovelace', 'Frøken Lister', 'John Smith', 'Anne Franks Bro', 'Rhodora', 'Wolf', 'Dolly PartonsJoleneved', 'Jeryd Mencken', 'Darren AronofskysMother']
# Processing batch: ['Ektoras Lygizos', 'John Patrick Amedori', 'Kraken', 'Sera', 'Andrzej Chyra', 'Hvorfor Wagenhofer', 'Marie Tourell Søderberg', 'James Laxton', 'Nino Soselia', 'Arizona']
# Processing batch: ['Jon Watts', 'per sekund', 'Johanna', 'Svend Auken', 'Nils', 'Mort Rifkin', 'David Simons', 'Malou', 'Plowright', 'Carsten']
# Processing batch: ['Benjamin Britten', 'Keith Raniere', 'Oscar-vinderenThe Social NetworkogEt', 'Rob Cohen', 'Bente Eskesen', 'W.G. Sebalds', 'Cleo Anthony', 'Guilt Trip', 'HendesHvidstengruppen', 'Ivan Locke']
# Processing batch: ['iGodzilla Minus Oneer', 'Joe iTiger Kingharmdirrende', 'Estelle Gettys', 'Jack Bright', 'Balder', 'Mangwana', 'Get Away', 'Philip', 'Pescatores', 'Laurent']
# Processing batch: ['Rhatha Phongam', 'Chuck Bass', 'Louise Banks', 'Walter Mortensen', 'Nikolaj Groth', 'Charlotte Ritter', 'Tillman', 'Sunny', 'Frodo', 'Amy Brenneman']
# Processing batch: ['Richard Regnvand', 'Virginie Efira', 'Staffords', 'Pjaltekunne', 'Emmett', 'Mr. Banks', 'Joeog', 'Alfred Bjerre Larsen', 'Elm StreetellerStab', 'Grantham']
# Processing batch: ['Alexander Dynans', 'Taraneh Alidoosti', 'Pierre Fresnay', 'Stepford Wives', 'Good Nurseen', 'Kevin Macdonalds dokumentarMarley', 'Margo', 'Birgitte Raaberg', 'Drengen Hugo', 'Felipe Guerrero']
# Processing batch: ['Kirsten Johnson', 'Arlos', 'Reggie Watts', 'Klaras', 'Ruby Dagnall', 'Lenka', 'Maxim', 'Cory', 'Agustín', 'nutids-Jim Carrey']
# Processing batch: ['formår', 'hvadRaging Bullgjorde', 'Cecily', 'John FordsForfølgeren', 'Husseins', 'Golda Rosheuvel', 'Bill Hader', 'Jeff Buckleys', 'Cyron Melville', 'Alice Finn Caspersen']
# Processing batch: ['Japón', 'Renners', 'James Wong', 'Roomfølger', 'Erling Groth', 'Madeleines Parishandler', 'Joy', 'Rikard', 'Gawains', 'Lifetimes']
# Processing batch: ['John Le Carre', 'Lolly Adefope', 'Kevin Spacey', 'Ingvars', 'Episode VII', 'Rosemary Myers', 'Simmons', 'James Lovell', 'Dickman', 'Porn Valley']
# Processing batch: ['Shimon Hayut', 'Tykke Obelix', 'Lady Whistledown', 'Stein Bagger-sagen', 'Ian McKellen', 'Michael Pitt', 'Jason Segel', 'Christopher Lowell', 'Fleet', 'Linus Wahlgren']
# Processing batch: ['Guzmáns', 'Julie Herdichek Batzers', 'Elodie Young', 'Stefan Pflug', 'Isa', 'Jonnys', 'Super Herotempoet', 'Lose', 'Nimrat Kaur', 'Villeneuve']
# Processing batch: ['Jovist', 'somFuryogEnd', 'Malekiths', 'Cornelis', 'toTexas Rangers', 'Margarethe Tiesels', 'Lady Susan Vernon', 'Graversens', 'Førerens', 'somDonnie Darko']
# Processing batch: ['Dorsas', 'Eric Goode', 'Magien', 'Delpy', 'Stephen Frears', 'Peter Brixtofte', 'Piratfeener', 'Ron Burgyndy', 'Johnnys', 'Claus Christensen']
# Processing batch: ['Sine Vadstrup Brooker', 'Eras Tour', 'Goghs', 'Martin Kongstads', 'Alzheimer', 'John Lee Hancock', 'Call Saul', 'Daves', 'Shota', 'Lex Luther']
# Processing batch: ['Lasse Hallström', 'Millicent Simmonds', 'Charlie Rose', 'Tómas Örn Tómasson', 'ogOslo', 'Lily Gladstone', 'Sigourney Weaver', 'Christians', 'Meyers', 'Lille Alfred']
# Processing batch: ['Paul W. Downs', 'Peder Skram', 'Máría', 'Actually', 'Jennifers', 'Mike White', 'Louis C.K.’s', 'Christopher Juul-Jensen', 'Molly Solverson', 'stålsatte indre']
# Processing batch: ['Kobo Daishis', 'Rambo', 'Johanne Milland', 'Leung', 'søren', 'Ann Woodward', 'Mzia Arabuli', 'Teater V. Den', 'Louise', 'Maja Angell']
# Processing batch: ['Frue', 'Jenna Ortegas', 'Gregg Araki', 'Paul VerhoevensRoboCopogStarship Troopers', 'Emas', 'Tim Burtons', 'Bryder', 'Case Against Adnan Syedgår', 'Mads Matthiesen', 'Filmpå']
# Processing batch: ['Lara Crofts', 'Barbara Topsøe-Rothenborg', 'Styx', 'Homs', 'Marokkosigter', 'Thomas Edison', 'Fredos', 'Bad Guys', 'Blair', 'Cristian Mungius']
# Processing batch: ['somStar Wars', 'Jean-Pierre Bacri', 'Micheline Roquebrune', 'Bee', 'Max Dillon', 'Generation Qføles', 'Austin Powers', 'Harvey', 'Kawases', 'Mario Bros.et']
# Processing batch: ['Carmiña Martínez', 'Rasmus Horskjær', 'Rasmus Bruuns', 'Naja Aggerholm', 'Valter', 'Buric', 'Rays', 'Maeve', 'José', 'Især Kaufmanas']
# Processing batch: ['Elizabeth Taylors', 'Mads Brüggers', 'Wayans', 'Joe Cole', 'Lady Birds', 'Christian Bengtson', 'Doug Limans', 'Mystic River', 'Midnight Gospel', 'Mantles']
# Processing batch: ['Gumpi', 'Graaf', 'J.G. Ballard-', 'Schönhaus', 'Robert Dølhus', 'Todd Field', 'Pipaluk Kreutzmann Jørgensen', 'Wellnesslangt', 'Girl Friday(1940', 'Side Effects']
# Processing batch: ['John Wayne Bobbitts', 'Garry MarshallsPretty Womanog François OzonsUng & smukdyrker', 'Inous', 'Finn Eriks', 'Wendts', 'Robins', 'Turners', 'Saori Hayami', 'fraIndiana Jones-', 'Marie Gøtzsche']
# Processing batch: ['J.R. afDaniel Ranieri', 'Moriarty', 'Andy Samberg', 'Esther Smith', 'Tim Burton', 'Tom Burke', '#', 'skød', 'Oliver Stones', 'Præsident Roosevelts']
# Processing batch: ['Allison', 'Chablis', 'Bricolage', 'Mothers', 'Mr. Poopybutthole', 'Joëlle Touma', 'Amanda Kernell', 'Fanny Ardants', 'Max Verstappen', 'Wilkin Brattle']
# Processing batch: ['Thomas Janes', 'Ashley Williams', 'Twin Peaks-figurer', 'Arne Bros', 'Skurken Ghost', 'Cheerful-projekt', 'Misumi', 'Fader Paul', 'Emily Mortimer', 'Cykling']
# Processing batch: ['Annabel', 'Adil El Arbi', 'Mike XXLogThe Martian', 'Carl Knasts', 'Masanobu Takayanagi', 'Evilpå', 'Molinas', 'Fitzgerald', 'Skip', 'Mark Millar']
# Processing batch: ['Eiza González', 'Christopher NolansMemento', 'Ester Martin Bergsmark', 'Dobbeltgængeraf Simon Mortensen', 'Bodil Nyboe Andersen', 'Ghislaine Maxwells', 'Michel Franco', 'Christopher Mintz-Plasse', 'Escalantes', 'Mossack']
# Processing batch: ['Crazy', 'Hans Meyer', 'Game Nightkombinerer', 'May el-Toukhy', 'Sonnys', 'Arnaud Bourons', 'Pollacks', 'Bader', 'Renzo', 'Ludlow']
# Processing batch: ['Abita', 'Rana', 'Santelmann', 'Joanna Mormont', 'andenSinister-film', 'Joe DiMaggio', 'Erikssons', 'Moderløse Brooklynfra', 'Emily Blunt', 'formår Lieshout']
# Processing batch: ['Nantucket', 'Mr. Hyde-agtigt', 'Jamilla', 'Lars Hjortshøj', 'Cyrus', 'Jon M. Chus', 'Jacksepticeye', 'Hudson', 'Bernard Hermann', 'Amandla Stenberg']
# Processing batch: ['Norma Jeane Bakers', 'Ben Sinclair', 'Orson Fortune', 'Max Manusog', 'Alice Howland', 'Adam McKay', 'Sergei Polunins', 'Kristine Froseth', 'Kenneth Branaghs Agatha', 'Fonda']
# Processing batch: ['Diktatoren', 'Cornelia', 'Günter Grass', 'Alejandro González Iñárritus', 'Kids', 'Jonathan Groff', 'This World Anymorenogle', 'Endsen', 'Ole Christian Madsens Ejersbo-\xadfilmatisering', 'Raoul Peck']
# Processing batch: ['Storygår Max', 'Catherine Deneuve', 'Lolas', 'Nyads', 'Queen', 'Kublai Khans', 'Wrestleren Sheila', 'Danis', 'Alyssa Sutherland', 'Anders Rønnov Klarlund']
# Processing batch: ['Niels Holstein Kaa', 'Gereon', 'Gmail', 'Oldman', 'Sezuan', 'Adnans', 'Midtom', 'Kacper', 'Andrias Høgennis', 'Steven Spielberg']
# Processing batch: ['Janusz Gajos', 'Jakob', 'musikfilmeneGravityogStaircase Sessionpå Ekko Shortlist', 'Restaurant Noma', 'Yaron Zilberman', 'Emmy', 'Merritt Wever', 'Strickland', 'Stephen McKinley Henderson', 'David Benioff']
# Processing batch: ['Anthony Scaramucci', 'Like Beckhamog', 'multiplot-sci-fiCloud Atlashavde', 'Collinilåner', 'Luca Cokers Bertram', 'Edda Björgvinsdóttir', 'Prins Harry', 'Klipperen Sophie', 'Toukos', 'Dahomeys']
# Processing batch: ['Les Mis', 'Jodie Comer', 'Woody Harrelson', 'Mia Wagner', 'MenIsle', 'Paul Walkers', 'Meng', 'Hunger Gamesnægtede', 'Wilhelm Tell', 'Lucinda Coxon']
# Processing batch: ['Anders Löfstedts', 'Peter Parker', 'Chp Pix', 'Red Barnet', 'Nicolas Cages Dracula', 'Roger Michell', 'Gus', 'Adrian Dunbar', 'Anna Mae Bullock', 'Palacehar latterliggørelsen']
# Processing batch: ['George Villiers', 'Jason Bournehar', 'Jeppe Nygren', 'Netflix-filmThe Ballad of Buster Scruggs', 'Jesse Jackson', 'Mohammad', 'Sissel Dalsgaard Thomsen', 'Outta Compton', 'Melinda Kinnaman', 'Veronicas']
# Processing batch: ['Burstyn', 'Ricky Baker', 'Blur', 'Billy Crystal', 'tilpas', 'Pat sarkastisk', 'forLong Shoter', 'dokumentarenAnimal Love', 'Kirsten Johnsons', 'Niecy Nash']
# Processing batch: ['Cityi Paris', 'Dee Rees', 'Petra Volpe', 'Messi', 'Bo Asdals', 'Jeppe Nygrens', 'World Wide Web', 'atBad Times', 'R.', 'Charlotte Vega']
# Processing batch: ['Nelly Ternan', 'Alma', 'Margit Auer', 'white', 'Helle', 'Nora Zehetner', 'Eagleoverbeviser', 'Aslaug Holms', 'Portia Doubleday', 'Ritva']
# Processing batch: ['Eborn', 'Vilhelm Blomgren', 'Marco Bellocchios', 'Mortensens', 'Josefine Ottesen', 'Krieps', 'Alicias', 'Skægget', 'Max Kestners', 'Borgman']
# Processing batch: ['Odysseus', 'McAllan', 'Batman Filmenmed', 'Hircano Soares', 'Paul W. S.', 'Sophie Turner', 'Jean-Claude Van Damme', 'Elleromde', 'Rory Kinnear', 'Judge Dredd']
# Processing batch: ['Boris Spassky', 'Hurley', 'Synnøve Macody Lund', 'Åge Stentoft', 'Alexandre O. Philippe', 'Ballsender', 'Take', 'Dorothy', 'Neus Ballús', 'Thomas Wheeler']
# Processing batch: ['Miss Marple-jakke', 'Oriana Fallaci', 'Franz Ferdinand', 'Ricky Bobby', 'John Grisham-filmatiseringerne', 'Ernie Hudson', 'White People', 'Rogelio', 'Manuskriptforfattere', 'Mick Jaggers']
# Processing batch: ['Ryan O’Neal', 'Yuen Woo-Ping', 'Selfish Gianter', 'Sklenar', 'Kelvin Harrison', 'Audrey Fleurot', 'Eugene Levy', 'Mester Shifu', 'Hearst', 'Daft Punks']
# Processing batch: ['Martyrs', 'Emil Trier', 'Arkham Asylum', 'Martin ScorsesesGoodfellasog Nicolas Winding RefnsPusher', 'Peter BergsLone Survivorogså', 'John CarpentersFlugtaktion New York', 'J.J. Abrams', 'Nicolas RoegsThe Man Who Fell', 'Milos FormansAmadeus', 'Marc Blucas']
# Processing batch: ['Outsiderlyder', 'ligesomBoogie NightsogMagnolia', 'Michael Angarano', 'Manhattans', 'Leif Andrée', 'Martin Scorseses', 'Nyong', 'Claus Villumsen', 'John Dean', 'Hoder']
# Processing batch: ['Orhan Pamuk', 'Rand Enterprises', 'Bukke Bruse', 'Mona', 'Leo Grandeer', 'Keith Stanfield', 'Ussing', 'Collodis', 'Kelly Gang', 'Nicole Kidman']
# Processing batch: ['Alex Le Domas', 'Eternity', 'Bernard-Henri Lévy', 'Amat', 'Crush', 'Henrik S. Holck', 'Wild Rosestår', 'Hunger Gamessluttede', 'atTime Trialmest', 'Christopher Darden']
# Processing batch: ['Last Panthersgriber', 'Charles Baudelaire', 'Moiraine', 'Sune', 'Anna Mathilde', 'Frank Grillo', 'Art Donaldson', 'jalousidramaer', 'Erins', 'Slahi']
# Processing batch: ['Sønderby Jepsen', 'Muffs', 'Ellen Franklin']

# %%
print(f'Length of the list with male names: {len(male_names)}') # 14,791
print(f'Length of the list with female names: {len(female_names)}') # 5,838
print(f'Length of the list with unknown names: {len(unknown_names)}') # 5,744
# Out:
# Length of the list with male names: 14791
# Length of the list with female names: 5838
# Length of the list with unknown names: 5744

# %%
# Create dfs for male, female, and unknown names
male_df = pd.DataFrame(male_names, columns = ["Name"])
female_df = pd.DataFrame(female_names, columns = ["Name"])

# Convert to lowercase + remove punc to align with the cleaned df
punc = r'[^\w\s]'
male_df["Name"] = male_df["Name"].str.lower().replace(punc, '', regex = True)
female_df["Name"] = female_df["Name"].str.lower().replace(punc, '', regex = True)

# Save to .csv files
male_df.to_csv("/work/SofieNørboMosegaard#5741/NLP/NLP-exam/data/male_names.csv", index = False)
female_df.to_csv("/work/SofieNørboMosegaard#5741/NLP/NLP-exam/data/female_names.csv", index = False)
